# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/home/remy/Projects/MyCine')

# %%
from lib import get_movie_infos

# %%
title = "le lion"
director = 'pinheiro'
infos = get_movie_infos(title, director)

# %%
infos
