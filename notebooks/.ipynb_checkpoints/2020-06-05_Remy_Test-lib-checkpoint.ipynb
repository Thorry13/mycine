# %%
# %load_ext autoreload
# %autoreload 2

# %%
from lib import get_movie_infos

# %%
title = "Pulp Fiction"
infos = get_movie_infos(title)

# %%
infos
# Out:
# {'title': 'Pulp Fiction',
#  'poster': 'http://fr.web.img5.acsta.net/c_215_290/medias/nmedia/18/36/02/52/18846059.jpg',
#  'date': datetime.datetime(1994, 10, 26, 0, 0),
#  'duration': datetime.timedelta(0, 8940),
#  'genres': ['Policier', 'Thriller'],
#  'directors': ['Quentin Tarantino'],
#  'actors': ['John Travolta', 'Samuel L. Jackson', 'Uma Thurman'],
#  'ratings': {'press': 4.4, 'spectators': 4.5},
#  'synopsis': "L'odyssée sanglante et burlesque de petits malfrats dans la jungle de Hollywood à travers trois histoires qui s'entremêlent."}
